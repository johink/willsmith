# %%
import numpy as np
import torch
import random

# %%
import torch.nn as nn
import torch.nn.functional as F

NUM_MOVES = 81 # Max number of valid moves in a game of NestedTTT

class NestedTTTNet(nn.Module):
    def __init__(self, inner_board_units = 32, outer_board_units = 64, final_units = 256, n_res_layers = 2):
        super(NestedTTTNet, self).__init__()
        self.n_res_layers = n_res_layers
        self.outer_board_units = outer_board_units
        self.final_units = final_units
        
        self.conv1 = nn.Conv2d(3, inner_board_units, 3, padding = 1)
        self.bn_inner = nn.BatchNorm2d(inner_board_units)
        self.res1 = nn.Conv2d(inner_board_units, inner_board_units, 3, padding = 1)
        
        self.conv2_collapse = nn.Conv2d(inner_board_units, outer_board_units, 3)
        self.bn_outer = nn.BatchNorm2d(outer_board_units)
        self.res2 = nn.Conv2d(outer_board_units, outer_board_units, 3, padding = 1)
        
        self.conv3_collapse = nn.Conv2d(outer_board_units, final_units, 3)
        self.bn_linear = nn.BatchNorm1d(final_units)
        
        self.policy_head = nn.Sequential(
            nn.Linear(final_units, NUM_MOVES),
            nn.Softmax(dim = 1)
        )
        
        self.value_head = nn.Sequential(
            nn.Linear(final_units, final_units // 2),
            nn.ReLU(),
            nn.Linear(final_units // 2, 1),
            nn.Tanh()
        )
        
    def forward(self, board_states):
        '''
        board_states.size() == (-1, 3, 3, 3, 3, 3)
                            == (batch_size, [x-owned, o-owned, turn-state], outer_row, outer_col, inner_row, inner_col)
        '''
        # Move the outer board states to the left so their intra-square can be resolved before introducing inter-square
        board_states = board_states.permute(0, 2, 3, 1, 4, 5).contiguous().view(-1, 3, 3, 3)
        
        x = F.relu(self.bn_inner(self.conv1(board_states)))
        for _ in range(self.n_res_layers):
            x_conv = F.relu(self.bn_inner(self.res1(x)))
            x = F.relu(x + self.bn_inner(self.res1(x_conv)))
            
        x = F.relu(self.bn_outer(self.conv2_collapse(x)))
        x = x.view(-1, 3, 3, self.outer_board_units).permute(0, 3, 1, 2).contiguous() # Move them back to the right
        
        for _ in range(self.n_res_layers):
            x_conv = F.relu(self.bn_outer(self.res2(x)))
            x = F.relu(x + self.bn_outer(self.res2(x_conv)))
        
        x = F.relu(self.bn_linear(self.conv3_collapse(x).view(-1, self.final_units)))
        
        policy = self.policy_head(x)
        value = self.value_head(x)
        
        return policy, value

# %%
import torch

class NestedTTT:

    anti_diag_tensor = torch.ByteTensor([[1 if r + c == 2 else 0 for c in range(3)] for r in range(3)])

    def __init__(self):
        #Board State Tensor
        #Outermost dimension:
        #First value represents Player 0's (X's) holdings, second represents O's
        #Third is filled with the number of the current player to move (0 = X, 1 = O)
        #Rest of the dimensions are (Outer Row, Outer Column, Inner Row, Inner Column)
        self.state = torch.full((3, 3, 3, 3, 3), 0, dtype = torch.float32, requires_grad = False)

        #Valid Move Tensor
        #(Outer Row, Outer Column, Inner Row, Inner Column)
        self.valid_moves = torch.full((3, 3, 3, 3), 1, dtype = torch.uint8, requires_grad = False)

        #Summary Board Tensor
        #(Player, Row, Column)
        self.summary_boards = torch.full((2, 3, 3), 0, dtype = torch.uint8, requires_grad = False)

        #Current Player
        self.current_player = 0
        
    def check_win(self, board):
        """
        Short-circuits if current player has less than 3 squares on the current board
        If they do, checks all rows, columns, and diagonals for a win

        Returns 0 if the current player did not win the board in question, or 1 if they did
        """
        if board.sum().item() < 3:
            return 0
        else:
            return (board.sum(0) == 3).any().item() or \
                   (board.sum(1) == 3).any().item() or \
                   (board.diag().sum() == 3).item()   or \
                   (board.masked_select(self.anti_diag_tensor).sum() == 3).item()

    def make_move(self, move):
        """
        Takes a move:
          ({0 for X, 1 for O}, outer row, outer col, inner row, inner col)
        Returns 1 if the move won the game, 0 otherwise
        """
        if not self.valid_moves[move[1:]].item():
            raise ValueError("Invalid move placement")
        if move[0] != self.state[2,0,0,0,0].item():
            raise ValueError("Only the current player can make a move")
        self.state[move] = 1
        self.valid_moves[move[1:]] = 0
        self.state[2] = 1 - self.state[2]

        if self.check_win(self.state[move[:3]]):
            self.summary_boards[move[:3]] = 1
            self.valid_moves[move[1:3]] = 0
            if self.check_win(self.summary_boards[move[0]]):
                self.valid_moves.fill_(0)
                return 1

        return 0

    def undo_move(self, move):
        if not self.state[move].item():
            raise ValueError("Can only undo where a move has been played")
        if move[0] == self.current_player:
            raise ValueError("Cannot undo a move for the current player")
        if self.state[(2,0,0,0,0)].item() != self.current_player:
            raise ValueError("Desynchronization between current player and state tensor")
        self.state[move] = 0
        self.valid_moves[move[1:3]] = 1 - self.state[:2, move[1], move[2]].sum(0)

        self.summary_boards[move[:3]] = 0
        self.state[2] = 1 - self.state[2]

    def switch_player(self):
        self.current_player = (self.current_player + 1) % 2
        
    def copy(self):
        c = self.__new__(NestedTTT)
        c.state = self.state.clone().detach().detach()
        c.valid_moves = self.valid_moves.clone().detach()
        c.summary_boards = self.summary_boards.clone().detach()
        c.current_player = self.current_player
        return c
    
    def reset(self):
        self.__init__()
        
    def get_valid_moves(self):
        return self.valid_moves.nonzero().tolist()

# %%
from math import sqrt
import random

EXPLORATION_PARAM = sqrt(2)

class Node:
    """
    Nodes represent a state in the game.  They can have edges which
    indicate legal actions to take from the state
    """
    def __init__(self, incoming_edge):
        self.parent_edge = incoming_edge
        self.leaf = True
        self.edges = dict()

    def choose_action(self, temperature = 1):
        if not self.edges:
            raise ValueError("Cannot choose action from an unexplored node")

        visits_exp = sum([edge.N ** (1 / temperature) for edge in self.edges.values()])
        thresh = random.random()
        cumsum = 0
        for action, edge in self.edges.items():
            cumsum = cumsum + edge.N ** (1 / temperature)
            if thresh < cumsum / visits_exp:
                return action

    def selection_step(self):
        if self.leaf:
            raise ValueError("Cannot perform selection step at a leaf")
        max_result = None
        max_action = None
        
        total_trials = sum([edge.N for edge in self.edges.values()])

        for action, edge in self.edges.items():
            current_estimate = edge.value_estimate(total_trials)
            if max_result is None or max_result < current_estimate:
                max_result = current_estimate
                max_action = action

        return max_action
    
    def expansion(self, actions, ps):
        if actions:
            for action, p in zip(actions, ps):
                self.edges[action] = Edge(self, p)
            self.leaf = False
        
    def backpropagate(self, value):
        if self.parent_edge is None:
            raise ValueError("Can't start backpropagating at the root")
        else:
            #Current state for player A is a result of the action (edge) chosen by player B
            #If the current state has a good value for player A, then it has a bad value for player B
            #Value of current state (node) is inverted to update value of action taken (incoming edge)
            self.parent_edge.backpropagate(-value)

class Edge:
    """
    Edges represent transitions between game states, initiated by an action
    Edges keep track of the number of visits, the estimated value of taking
    their associated action, and the prior probability of taking that action
    """
    def __init__(self, origin, p):
        self.origin = origin
        self.destination = Node(self)
        self.N = 0 # Visits
        self.Q = 0 # Value estimate
        self.P = p # NN-generated prior

    def backpropagate(self, value):
        self.N += 1
        self.Q = self.Q * ((self.N - 1) / self.N) + value / self.N
        
        #Alternating edges indicate alternating player actions, so the value of states will be inverted at each layer
        if self.origin.parent_edge is not None:
            self.origin.parent_edge.backpropagate(-value)

    def value_estimate(self, parent_trials):
        return self.Q + EXPLORATION_PARAM * self.P * parent_trials ** .5 / (1 + self.N)
    
    def __str__(self):
        return "N={}, Q={}, P={}".format(self.N, self.Q, self.P)
    
    def __repr__(self):
        return str(self)

# %%
from time import time
import logging

class AlphaMCTSAgent:
    def __init__(self, control_net = None):
        self.root = Node(None)
        self.playout_total = 0
        self.control_net = control_net
        
    def update_control_net(self, control_net):
        self.control_net = control_net
        
    def search(self, game, turn_num, allotted_playouts = 800):
        if self.control_net is None:
            raise ValueError("Control net must be set before starting searches")
        playouts = 0

        start_time = time()
        while playouts < allotted_playouts:
            current_game = game.copy()
            current_game, node = self._selection(current_game)

            actions = current_game.get_valid_moves()
            ps, v = self.control_net(current_game.state.unsqueeze(0))
            ps.squeeze_()
            v = v.squeeze().item()

            indices = [self.ttt_position_to_index(action) for action in actions]
            
            actions = [(round(current_game.state[2,0,0,0,0].item()),) + tuple(action) for action in actions]

            node.expansion(actions, ps.detach().numpy()[indices])
            
            if id(self.root) != id(node):
                node.backpropagate(v)

            playouts += 1

        temp = 1 if turn_num < 30 else .1
        max_action = self.root.choose_action(temp)
        
        # debug info
        self.playout_total = playouts
        self.action_node = max_action
        
        actions = game.get_valid_moves()
        indices = [self.ttt_position_to_index(action) for action in actions]
        actions = [(round(game.state[2,0,0,0,0].item()),) + tuple(action) for action in actions]
        
        mcts_probs = {indices[i]: self.root.edges[actions[i]].N for i in range(len(indices))}
        total_trials = sum(mcts_probs.values())
        mcts_probs = [mcts_probs.get(x, 0) / total_trials for x in range(81)]
        
        return max_action, mcts_probs
    
    def take_action(self, action):
        try:
            self.root = self.root.edges[action].destination
        except KeyError:
            print("Action not found, throwing away tree")
            self.reset()
            
    def reset(self):
        self.root = Node(None)

    def _selection(self, state):
        """
        Progress through the tree of Nodes, starting at the root, until a
        leaf is found or there are unexplored actions at the level we are
        exploring.

        Uses the UCT algorithm to determine which nodes to progress to.
        """
        node = self.root
        while not node.leaf:
            move = node.selection_step()
            node = node.edges[move].destination
            state.make_move(move)
        return state, node
    
    @staticmethod
    def index_to_ttt_position(idx):
        return idx // 27 % 3, idx // 9 % 3, idx // 3 % 3, idx % 3

    @staticmethod
    def ttt_position_to_index(position):
        return position[0] * 27 + position[1] * 9 + position[2] * 3 + position[3]

# %%
from collections import deque
import random

class ReplayBuffer:
    def __init__(self, capacity = 100000):
        self.buffer = deque(maxlen = capacity)
    
    def push(self, data):
        self.buffer.append(data)
        
    def extend(self, data):
        self.buffer.extend(data)
        
    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)
    
    def __len__(self):
        return len(self.buffer)

# %%
# One class that has access to:
  # Game simulation
  # Control network
  # Current network
  # Replay buffer
  # MCTS agent
  # Training code  -- Another process?

# %%
import torch
import random

def zero_gen():
    while True:
        yield 0

def one_neg_one_gen():
    while True:
        yield 1
        yield -1

class SelfPlayTrainer:
    def __init__(self, agent, game, buffer_file = None, weights_file = None, n_batches = 0):
        self.agent = agent
        self.game = game
        self.replay_buffer = ReplayBuffer()
        
        if buffer_file is not None:
            self.replay_buffer.buffer = pickle.load(open(buffer_file, "rb"))
        
        self.current_network = NestedTTTNet()
        self.control_network = NestedTTTNet()
        
        if weights_file is not None:
            self.control_network.load_state_dict(torch.load(weights_file))
        
        self.current_network.load_state_dict(self.control_network.state_dict())
        self.control_network.eval()
        self.current_network.train()
        
        self.agent.update_control_net(self.control_network)
        
        self.n_batches = n_batches
        
        self.optim = torch.optim.Adam(self.current_network.parameters(), lr = .01, weight_decay = 10e-4)
    
    def generate_self_play_data(self, n_games = 100):
        for _ in range(n_games):
            turn_num = 0
            self.game.reset()
            self.agent.reset()
            result = 0
            player_num = 0

            states = []
            move_vectors = []

            while len(self.game.get_valid_moves()) > 0:
                move, move_probs = self.agent.search(self.game.copy(), turn_num, allotted_playouts = 400)

                states.append(self.game.state.tolist())
                move_vectors.append(move_probs)

                result = self.game.make_move(move)
                if not result:
                    self.game.switch_player()
                    self.agent.take_action(move)
                    turn_num += 1
                    player_num = (player_num + 1) % 2

            if not result:
                self.replay_buffer.extend(list(zip(states, move_vectors, zero_gen())))
            else:
                self.replay_buffer.extend(list(zip(states[::-1], move_vectors[::-1], one_neg_one_gen()))[::-1])

    def compare_control_to_train(self):
        self.current_network.eval()
        old_agent = AlphaMCTSAgent(control_net = self.control_network)
        new_agent = AlphaMCTSAgent(control_net = self.current_network)
        
        agents = [old_agent, new_agent]
        
        wins = 0
        ties = 0
        
        game = self.game.copy()
        
        for game_num in range(100):
            game.reset()
            agents[0].reset()
            agents[1].reset()
            result = 0
            player_num = game_num // 50 #Both take first turn 50 times
            turn_num = 100 #Turn down the temperature
            
            while len(game.get_valid_moves()) > 0:
                move, _ = agents[player_num].search(game.copy(), turn_num, allotted_playouts = 800)
                _, _ = agents[1 - player_num].search(game.copy(), turn_num, allotted_playouts = 800)

                result = self.game.make_move(move)
                if not result:
                    game.switch_player()
                    agents[0].take_action(move)
                    agents[1].take_action(move)
                    player_num = (player_num + 1) % 2

            if not result:
                ties += 1
            elif result and current_player == 1:
                wins += 1
        
        if wins + .5 * ties >= 55:
            print("Challenger network won {} games and tied {} games; it becomes new control network".format(wins, ties))
            torch.save(self.current_network.state_dict(), "control_weights_{}.pth".format(self.n_batches))
            self.control_network.load_state_dict(self.current_network.state_dict())
        else:
            print("Challenger network not sufficiently better; {} wins and {} ties".format(wins, ties))
        
        self.control_network.eval()
        self.current_network.train()            
    
    def train_on_batch(self, batch_size = 32):
        if len(self.replay_buffer) < batch_size:
            return
        
        self.current_network.train()
        
        sample = self.replay_buffer.sample(batch_size)
        states, probs, rewards = zip(*sample)
        states = torch.FloatTensor(states).requires_grad_(True)
        probs = torch.FloatTensor(probs).requires_grad_(True)
        rewards = torch.FloatTensor(rewards).unsqueeze(1).requires_grad_(True)
        self.optim.zero_grad()
        
        ps, vs = trainer.current_network(states)
        
        loss = torch.nn.functional.mse_loss(vs, rewards) - (ps.log() * probs).sum()
        loss.backward()
        
        self.optim.step()
        
        self.n_batches += 1
        
        return loss.item()
    
    def run(self, total_runs = 10, self_play_games = 100, training_batches = 200, batch_size = 32):
        losses = []
        for run_num in range(1, total_runs+1):
            print("Run {} of {}".format(run_num, total_runs))
            for selfplay_num in range(1, self_play_games + 1):
                self.generate_self_play_data(1)
                print("\tFinished self-play game {} of {} (Buffer size {})".format(selfplay_num, self_play_games, len(self.replay_buffer)))
            print("Finished {} self-play games".format(self_play_games))
            for _ in range(training_batches):
                losses.append(self.train_on_batch(batch_size))
                if len(losses) == 5:
                    print("\tLoss for last 5 batches: {}".format(sum(losses)))
                    losses = []
        
        self.compare_control_to_train()

# %%
trainer = SelfPlayTrainer(AlphaMCTSAgent(), NestedTTT())

# %%
trainer.run(1, 0, 30000)
# Out:
# Run 1 of 1
# Finished 0 self-play games
# 	Loss for last 5 batches: 619.5038223266602
# 	Loss for last 5 batches: 616.9755706787109
# 	Loss for last 5 batches: 632.480094909668
# 	Loss for last 5 batches: 627.7477569580078
# 	Loss for last 5 batches: 620.2631530761719
# 	Loss for last 5 batches: 620.7949600219727
# 	Loss for last 5 batches: 622.7703094482422
# 	Loss for last 5 batches: 614.2876358032227
# 	Loss for last 5 batches: 615.6514434814453
# 	Loss for last 5 batches: 622.0893859863281
# 	Loss for last 5 batches: 608.3180770874023
# 	Loss for last 5 batches: 635.6034622192383
# 	Loss for last 5 batches: 632.2602920532227
# 	Loss for last 5 batches: 625.8481369018555
# 	Loss for last 5 batches: 616.8213806152344
# 	Loss for last 5 batches: 622.3674163818359
# 	Loss for last 5 batches: 629.5902633666992
# 	Loss for last 5 batches: 622.5725173950195
# 	Loss for last 5 batches: 633.1866683959961
# 	Loss for last 5 batches: 623.2088623046875
# 	Loss for last 5 batches: 619.0293807983398
# 	Loss for last 5 batches: 623.9105072021484
# 	Loss for last 5 batches: 628.9424514770508
# 	Loss for last 5 batches: 625.931526184082
# 	Loss for last 5 batches: 610.053337097168
# 	Loss for last 5 batches: 622.0666732788086
# 	Loss for last 5 batches: 629.0951919555664
# 	Loss for last 5 batches: 635.9441146850586
# 	Loss for last 5 batches: 633.3354339599609
# 	Loss for last 5 batches: 635.2109146118164
# 	Loss for last 5 batches: 630.1917572021484
# 	Loss for last 5 batches: 632.5392608642578
# 	Loss for last 5 batches: 619.0247039794922
# 	Loss for last 5 batches: 636.0127258300781
# 	Loss for last 5 batches: 625.0173645019531
# 	Loss for last 5 batches: 616.9605102539062
# 	Loss for last 5 batches: 621.544303894043
# 	Loss for last 5 batches: 623.0266571044922
# 	Loss for last 5 batches: 624.6500854492188
# 	Loss for last 5 batches: 610.0750045776367
# 	Loss for last 5 batches: 633.1982574462891
# 	Loss for last 5 batches: 635.6292953491211
# 	Loss for last 5 batches: 633.3061065673828
# 	Loss for last 5 batches: 631.4914093017578
# 	Loss for last 5 batches: 630.0514450073242
# 	Loss for last 5 batches: 631.0855331420898
# 	Loss for last 5 batches: 624.3494644165039
# 	Loss for last 5 batches: 632.489631652832
# 	Loss for last 5 batches: 635.6402816772461
# 	Loss for last 5 batches: 616.1384124755859
# 	Loss for last 5 batches: 608.7155303955078
# 	Loss for last 5 batches: 623.7698593139648
# 	Loss for last 5 batches: 612.3407745361328
# 	Loss for last 5 batches: 625.4720840454102
# 	Loss for last 5 batches: 607.0751419067383
# 	Loss for last 5 batches: 619.3949203491211
# 	Loss for last 5 batches: 625.5128173828125
# 	Loss for last 5 batches: 631.4954223632812
# 	Loss for last 5 batches: 623.4013214111328
# 	Loss for last 5 batches: 634.2376174926758
# 	Loss for last 5 batches: 635.826774597168
# 	Loss for last 5 batches: 640.3251037597656
# 	Loss for last 5 batches: 621.3145065307617
# 	Loss for last 5 batches: 626.4475631713867
# 	Loss for last 5 batches: 638.8819122314453
# 	Loss for last 5 batches: 624.235710144043
# 	Loss for last 5 batches: 621.2677688598633
# 	Loss for last 5 batches: 631.6186141967773
# 	Loss for last 5 batches: 615.9601287841797
# 	Loss for last 5 batches: 624.6528244018555
# 	Loss for last 5 batches: 627.667350769043
# 	Loss for last 5 batches: 620.6973495483398
# 	Loss for last 5 batches: 635.3025970458984
# 	Loss for last 5 batches: 620.2787933349609
# 	Loss for last 5 batches: 626.4363555908203
# 	Loss for last 5 batches: 631.7474899291992
# 	Loss for last 5 batches: 632.181022644043
# 	Loss for last 5 batches: 628.8011016845703
# 	Loss for last 5 batches: 625.2622299194336
# 	Loss for last 5 batches: 624.3001937866211
# 	Loss for last 5 batches: 614.4621734619141
# 	Loss for last 5 batches: 617.5425796508789
# 	Loss for last 5 batches: 627.0166015625
# 	Loss for last 5 batches: 630.6122741699219
# 	Loss for last 5 batches: 627.5378875732422
# 	Loss for last 5 batches: 634.9211654663086
# 	Loss for last 5 batches: 617.2296142578125
# 	Loss for last 5 batches: 631.5394668579102
# 	Loss for last 5 batches: 608.7943344116211
# 	Loss for last 5 batches: 630.1486434936523
# 	Loss for last 5 batches: 628.9432983398438
# 	Loss for last 5 batches: 630.3160095214844
# 	Loss for last 5 batches: 629.7422943115234
# 	Loss for last 5 batches: 628.7733154296875
# 	Loss for last 5 batches: 601.9319381713867
# 	Loss for last 5 batches: 619.7256469726562
# 	Loss for last 5 batches: 624.8586502075195
# 	Loss for last 5 batches: 618.1060333251953
# 	Loss for last 5 batches: 627.8738555908203
# 	Loss for last 5 batches: 626.6982192993164
# 	Loss for last 5 batches: 624.3482437133789
# 	Loss for last 5 batches: 625.5033569335938
# 	Loss for last 5 batches: 633.8355865478516
# 	Loss for last 5 batches: 624.0412521362305
# 	Loss for last 5 batches: 616.1592102050781
# 	Loss for last 5 batches: 623.724365234375
# 	Loss for last 5 batches: 619.4911651611328
# 	Loss for last 5 batches: 637.4749221801758
# 	Loss for last 5 batches: 631.9041519165039
# 	Loss for last 5 batches: 631.406867980957
# 	Loss for last 5 batches: 623.7531890869141
# 	Loss for last 5 batches: 622.7732696533203
# 	Loss for last 5 batches: 635.7262115478516
# 	Loss for last 5 batches: 629.1048812866211
# 	Loss for last 5 batches: 622.0750579833984
# 	Loss for last 5 batches: 623.7046813964844
# 	Loss for last 5 batches: 622.4791259765625
# 	Loss for last 5 batches: 623.8491821289062
# 	Loss for last 5 batches: 621.1912612915039
# 	Loss for last 5 batches: 629.9499359130859
# 	Loss for last 5 batches: 628.2140579223633
# 	Loss for last 5 batches: 615.1989059448242
# 	Loss for last 5 batches: 616.5170593261719
# 	Loss for last 5 batches: 624.9266357421875
# 	Loss for last 5 batches: 617.8874969482422
# 	Loss for last 5 batches: 613.7147216796875
# 	Loss for last 5 batches: 621.3218078613281
# 	Loss for last 5 batches: 625.7087631225586
# 	Loss for last 5 batches: 638.1687927246094
# 	Loss for last 5 batches: 631.7066268920898
# 	Loss for last 5 batches: 629.8623123168945
# 	Loss for last 5 batches: 625.7425003051758
# 	Loss for last 5 batches: 624.7902069091797
# 	Loss for last 5 batches: 619.9980545043945
# 	Loss for last 5 batches: 626.1351318359375
# 	Loss for last 5 batches: 631.0940780639648
# 	Loss for last 5 batches: 623.3927688598633
# 	Loss for last 5 batches: 625.3732070922852
# 	Loss for last 5 batches: 621.2343902587891
# 	Loss for last 5 batches: 621.9661254882812
# 	Loss for last 5 batches: 623.7322998046875
# 	Loss for last 5 batches: 610.8399353027344
# 	Loss for last 5 batches: 611.5670166015625
# 	Loss for last 5 batches: 630.2147827148438
# 	Loss for last 5 batches: 615.9677963256836
# 	Loss for last 5 batches: 621.6352310180664
# 	Loss for last 5 batches: 625.320915222168
# 	Loss for last 5 batches: 620.3578567504883
# 	Loss for last 5 batches: 622.1907424926758
# 	Loss for last 5 batches: 607.9027404785156
# 	Loss for last 5 batches: 617.4214935302734
# 	Loss for last 5 batches: 624.6236267089844
# 	Loss for last 5 batches: 627.3301696777344
# 	Loss for last 5 batches: 616.6660842895508
# 	Loss for last 5 batches: 626.7412872314453
# 	Loss for last 5 batches: 621.2227325439453
# 	Loss for last 5 batches: 628.3713989257812
# 	Loss for last 5 batches: 636.2384872436523
# 	Loss for last 5 batches: 632.8589782714844
# 	Loss for last 5 batches: 623.4082794189453
# 	Loss for last 5 batches: 625.2748336791992
# 	Loss for last 5 batches: 627.9150772094727
# 	Loss for last 5 batches: 631.8835983276367
# 	Loss for last 5 batches: 620.7140884399414
# 	Loss for last 5 batches: 616.7926330566406
# 	Loss for last 5 batches: 615.7770767211914
# 	Loss for last 5 batches: 616.2289581298828
# 	Loss for last 5 batches: 620.3881988525391
# 	Loss for last 5 batches: 630.8719024658203
# 	Loss for last 5 batches: 626.969856262207
# 	Loss for last 5 batches: 624.3513412475586
# 	Loss for last 5 batches: 635.9800567626953
# 	Loss for last 5 batches: 625.4366455078125
# 	Loss for last 5 batches: 620.4343643188477
# 	Loss for last 5 batches: 627.7637405395508
# 	Loss for last 5 batches: 626.1135482788086
# 	Loss for last 5 batches: 625.4346160888672
# 	Loss for last 5 batches: 606.0241088867188
# 	Loss for last 5 batches: 624.652717590332
# 	Loss for last 5 batches: 619.5241622924805
# 	Loss for last 5 batches: 638.8545303344727
# 	Loss for last 5 batches: 619.8870468139648
# 	Loss for last 5 batches: 634.2894134521484
# 	Loss for last 5 batches: 618.8099899291992
# 	Loss for last 5 batches: 625.4846801757812
# 	Loss for last 5 batches: 628.5422973632812
# 	Loss for last 5 batches: 625.5573425292969
# 	Loss for last 5 batches: 631.7596054077148
# 	Loss for last 5 batches: 618.2097930908203
# 	Loss for last 5 batches: 617.1615829467773
# 	Loss for last 5 batches: 636.5772552490234
# 	Loss for last 5 batches: 639.4394226074219
# 	Loss for last 5 batches: 625.2365188598633
# 	Loss for last 5 batches: 624.9333419799805
# 	Loss for last 5 batches: 624.4702377319336
# 	Loss for last 5 batches: 626.2000045776367
# 	Loss for last 5 batches: 613.6240615844727
# 	Loss for last 5 batches: 613.2272644042969
# 	Loss for last 5 batches: 627.3467102050781
# 	Loss for last 5 batches: 618.4839553833008
# 	Loss for last 5 batches: 624.8309860229492
# 	Loss for last 5 batches: 633.0959396362305
# 	Loss for last 5 batches: 614.5800476074219
# 	Loss for last 5 batches: 610.8126831054688
# 	Loss for last 5 batches: 619.8279190063477
# 	Loss for last 5 batches: 624.5617599487305
# 	Loss for last 5 batches: 614.26171875
# 	Loss for last 5 batches: 623.0623550415039
# 	Loss for last 5 batches: 632.0245895385742
# 	Loss for last 5 batches: 622.6246337890625
# 	Loss for last 5 batches: 621.5970001220703
# 	Loss for last 5 batches: 620.8227005004883
# 	Loss for last 5 batches: 615.6838226318359
# 	Loss for last 5 batches: 621.6971282958984
# 	Loss for last 5 batches: 630.3599090576172
# 	Loss for last 5 batches: 612.0781707763672
# 	Loss for last 5 batches: 628.0154647827148
# 	Loss for last 5 batches: 620.8126831054688
# 	Loss for last 5 batches: 621.2403411865234
# 	Loss for last 5 batches: 613.3382186889648
# 	Loss for last 5 batches: 624.2150421142578
# 	Loss for last 5 batches: 621.6616973876953
# 	Loss for last 5 batches: 622.8495483398438
# 	Loss for last 5 batches: 628.2007369995117
# 	Loss for last 5 batches: 614.8039779663086
# 	Loss for last 5 batches: 630.2217102050781
# 	Loss for last 5 batches: 623.4306869506836
# 	Loss for last 5 batches: 630.165397644043
# 	Loss for last 5 batches: 617.216796875
# 	Loss for last 5 batches: 626.2199249267578
# 	Loss for last 5 batches: 628.0803451538086
# 	Loss for last 5 batches: 623.9182052612305
# 	Loss for last 5 batches: 628.3602447509766
# 	Loss for last 5 batches: 636.8720474243164
# 	Loss for last 5 batches: 631.735466003418
# 	Loss for last 5 batches: 636.786506652832
# 	Loss for last 5 batches: 638.0334930419922
# 	Loss for last 5 batches: 631.3274002075195
# 	Loss for last 5 batches: 628.3670196533203
# 	Loss for last 5 batches: 630.8590774536133
# 	Loss for last 5 batches: 633.3165664672852
# 	Loss for last 5 batches: 627.6508941650391
# 	Loss for last 5 batches: 621.7079162597656
# 	Loss for last 5 batches: 617.110237121582
# 	Loss for last 5 batches: 629.173698425293
# 	Loss for last 5 batches: 629.6767349243164
# 	Loss for last 5 batches: 623.0547790527344
# 	Loss for last 5 batches: 629.7550582885742
# 	Loss for last 5 batches: 617.0681228637695
# 	Loss for last 5 batches: 624.6975784301758
# 	Loss for last 5 batches: 621.004524230957
# 	Loss for last 5 batches: 630.2412948608398
# 	Loss for last 5 batches: 623.5226516723633
# 	Loss for last 5 batches: 620.566047668457
# 	Loss for last 5 batches: 631.7018585205078
# 	Loss for last 5 batches: 636.8999633789062
# 	Loss for last 5 batches: 620.5234756469727
# 	Loss for last 5 batches: 616.6037216186523
# 	Loss for last 5 batches: 625.1573257446289
# 	Loss for last 5 batches: 612.9139709472656
# 	Loss for last 5 batches: 625.5251083374023
# 	Loss for last 5 batches: 612.3149490356445
# 	Loss for last 5 batches: 626.2450790405273
# 	Loss for last 5 batches: 636.6444625854492
# 	Loss for last 5 batches: 615.1092071533203
# 	Loss for last 5 batches: 622.2718048095703
# 	Loss for last 5 batches: 630.9250030517578
# 	Loss for last 5 batches: 623.4099426269531
# 	Loss for last 5 batches: 624.5094146728516
# 	Loss for last 5 batches: 620.2509689331055
# 	Loss for last 5 batches: 623.8815002441406
# 	Loss for last 5 batches: 619.5197830200195
# 	Loss for last 5 batches: 618.3387069702148
# 	Loss for last 5 batches: 624.6064605712891
# 	Loss for last 5 batches: 622.7291946411133
# 	Loss for last 5 batches: 630.7686996459961
# 	Loss for last 5 batches: 609.3274612426758
# 	Loss for last 5 batches: 626.3675231933594
# 	Loss for last 5 batches: 622.0224533081055
# 	Loss for last 5 batches: 619.3835601806641
# 	Loss for last 5 batches: 618.1070175170898
# 	Loss for last 5 batches: 639.2757720947266
# 	Loss for last 5 batches: 615.7350921630859
# 	Loss for last 5 batches: 608.0935440063477
# 	Loss for last 5 batches: 623.8096389770508
# 	Loss for last 5 batches: 615.0057144165039
# 	Loss for last 5 batches: 621.2952041625977
# 	Loss for last 5 batches: 614.5267944335938
# 	Loss for last 5 batches: 641.6331100463867
# 	Loss for last 5 batches: 625.3283157348633
# 	Loss for last 5 batches: 622.9252166748047
# 	Loss for last 5 batches: 619.8666915893555
# 	Loss for last 5 batches: 621.3510131835938
# 	Loss for last 5 batches: 626.1902618408203
# 	Loss for last 5 batches: 615.3489303588867
# 	Loss for last 5 batches: 638.1214599609375
# 	Loss for last 5 batches: 628.1091461181641
# 	Loss for last 5 batches: 617.1858825683594
# 	Loss for last 5 batches: 620.5074615478516
# 	Loss for last 5 batches: 625.739013671875
# 	Loss for last 5 batches: 619.3544998168945
# 	Loss for last 5 batches: 623.4970703125
# 	Loss for last 5 batches: 627.306755065918
# 	Loss for last 5 batches: 630.5632019042969
# 	Loss for last 5 batches: 615.7280578613281
# 	Loss for last 5 batches: 616.6952972412109
# 	Loss for last 5 batches: 633.641242980957
# 	Loss for last 5 batches: 635.0080032348633
# 	Loss for last 5 batches: 620.5587921142578
# 	Loss for last 5 batches: 626.3732147216797
# 	Loss for last 5 batches: 629.6554870605469
# 	Loss for last 5 batches: 619.2777709960938
# 	Loss for last 5 batches: 619.5823593139648
# 	Loss for last 5 batches: 619.653564453125
# 	Loss for last 5 batches: 625.9331817626953
# 	Loss for last 5 batches: 609.7490844726562
# 	Loss for last 5 batches: 618.7972183227539
# 	Loss for last 5 batches: 617.2258529663086
# 	Loss for last 5 batches: 620.7806167602539
# 	Loss for last 5 batches: 610.4274978637695
# 	Loss for last 5 batches: 621.9973068237305
# 	Loss for last 5 batches: 626.5814743041992
# 	Loss for last 5 batches: 613.5511627197266
# 	Loss for last 5 batches: 616.7917327880859
# 	Loss for last 5 batches: 625.8740997314453
# 	Loss for last 5 batches: 630.5277938842773
# 	Loss for last 5 batches: 616.9261703491211
# 	Loss for last 5 batches: 626.1593475341797
# 	Loss for last 5 batches: 627.0359268188477
# 	Loss for last 5 batches: 625.1901321411133
# 	Loss for last 5 batches: 622.801025390625
# 	Loss for last 5 batches: 614.0411071777344
# 	Loss for last 5 batches: 615.1775665283203
# 	Loss for last 5 batches: 628.8655395507812
# 	Loss for last 5 batches: 643.7599334716797
# 	Loss for last 5 batches: 630.4568252563477
# 	Loss for last 5 batches: 619.9371566772461
# 	Loss for last 5 batches: 624.8281021118164
# 	Loss for last 5 batches: 625.052604675293
# 	Loss for last 5 batches: 623.2396697998047
# 	Loss for last 5 batches: 626.1429290771484
# 	Loss for last 5 batches: 621.7741317749023
# 	Loss for last 5 batches: 619.9672393798828
# 	Loss for last 5 batches: 621.4961547851562
# 	Loss for last 5 batches: 622.0844116210938
# 	Loss for last 5 batches: 623.0344161987305
# 	Loss for last 5 batches: 609.347526550293
# 	Loss for last 5 batches: 628.1060180664062
# 	Loss for last 5 batches: 621.7297973632812
# 	Loss for last 5 batches: 621.6029434204102
# 	Loss for last 5 batches: 613.7329864501953
# 	Loss for last 5 batches: 632.0200958251953
# 	Loss for last 5 batches: 618.8061599731445
# 	Loss for last 5 batches: 619.4936218261719
# 	Loss for last 5 batches: 622.3256072998047
# 	Loss for last 5 batches: 618.342155456543
# 	Loss for last 5 batches: 626.4913330078125
# 	Loss for last 5 batches: 631.6521224975586
# 	Loss for last 5 batches: 622.900016784668
# 	Loss for last 5 batches: 636.8626327514648
# 	Loss for last 5 batches: 625.9766464233398
# 	Loss for last 5 batches: 625.4710006713867
# 	Loss for last 5 batches: 619.4396514892578
# 	Loss for last 5 batches: 619.8143768310547
# 	Loss for last 5 batches: 612.7140121459961
# 	Loss for last 5 batches: 625.5134735107422
# 	Loss for last 5 batches: 630.646842956543
# 	Loss for last 5 batches: 624.915771484375
# 	Loss for last 5 batches: 615.413200378418
# 	Loss for last 5 batches: 616.9908676147461
# 	Loss for last 5 batches: 619.8074417114258
# 	Loss for last 5 batches: 614.863037109375
# 	Loss for last 5 batches: 614.7339096069336
# 	Loss for last 5 batches: 624.1297607421875
# 	Loss for last 5 batches: 616.0171203613281
# 	Loss for last 5 batches: 621.5968933105469
# 	Loss for last 5 batches: 613.0711898803711
# 	Loss for last 5 batches: 633.8810195922852
# 	Loss for last 5 batches: 622.2598495483398
# 	Loss for last 5 batches: 620.2450561523438
# 	Loss for last 5 batches: 619.9661178588867
# 	Loss for last 5 batches: 614.572395324707
# 	Loss for last 5 batches: 630.0176620483398
# 	Loss for last 5 batches: 631.5188674926758
# 	Loss for last 5 batches: 620.9067153930664
# 	Loss for last 5 batches: 610.4141693115234
# 	Loss for last 5 batches: 620.3015060424805
# 	Loss for last 5 batches: 630.3010711669922
# 	Loss for last 5 batches: 608.8565444946289
# 	Loss for last 5 batches: 629.8126602172852
# 	Loss for last 5 batches: 617.3827514648438
# 	Loss for last 5 batches: 630.1281509399414
# 	Loss for last 5 batches: 630.411247253418
# 	Loss for last 5 batches: 628.6357879638672
# 	Loss for last 5 batches: 628.7556228637695
# 	Loss for last 5 batches: 632.1241760253906
# 	Loss for last 5 batches: 624.2326889038086
# 	Loss for last 5 batches: 612.6245346069336
# 	Loss for last 5 batches: 610.5173568725586
# 	Loss for last 5 batches: 624.312873840332
# 	Loss for last 5 batches: 618.0295715332031
# 	Loss for last 5 batches: 619.5148620605469
# 	Loss for last 5 batches: 625.0140991210938
# 	Loss for last 5 batches: 624.9476623535156
# 	Loss for last 5 batches: 626.6191558837891
# 	Loss for last 5 batches: 627.9533004760742
# 	Loss for last 5 batches: 623.5210647583008
# 	Loss for last 5 batches: 616.4526062011719
# 	Loss for last 5 batches: 635.5219421386719
# 	Loss for last 5 batches: 618.8226852416992
# 	Loss for last 5 batches: 617.676139831543
# 	Loss for last 5 batches: 625.7359085083008
# 	Loss for last 5 batches: 614.0782470703125
# 	Loss for last 5 batches: 627.0133743286133
# 	Loss for last 5 batches: 629.1224594116211
# 	Loss for last 5 batches: 624.6951446533203
# 	Loss for last 5 batches: 626.8124923706055
# 	Loss for last 5 batches: 624.2846527099609
# 	Loss for last 5 batches: 621.6113586425781
# 	Loss for last 5 batches: 622.1214065551758
# 	Loss for last 5 batches: 629.1768951416016
# 	Loss for last 5 batches: 610.2124404907227
# 	Loss for last 5 batches: 615.6143417358398
# 	Loss for last 5 batches: 613.1295776367188
# 	Loss for last 5 batches: 637.6886825561523
# 	Loss for last 5 batches: 616.6588134765625
# 	Loss for last 5 batches: 625.666259765625
# 	Loss for last 5 batches: 608.7724533081055
# 	Loss for last 5 batches: 631.0977478027344
# 	Loss for last 5 batches: 627.5822525024414
# 	Loss for last 5 batches: 619.4261322021484
# 	Loss for last 5 batches: 615.554313659668
# 	Loss for last 5 batches: 613.5966796875
# 	Loss for last 5 batches: 633.9188003540039
# 	Loss for last 5 batches: 613.8359222412109
# 	Loss for last 5 batches: 613.2398452758789
# 	Loss for last 5 batches: 628.9351959228516
# 	Loss for last 5 batches: 632.0218734741211
# 	Loss for last 5 batches: 623.4862289428711
# 	Loss for last 5 batches: 626.1008224487305
# 	Loss for last 5 batches: 622.2464218139648
# 	Loss for last 5 batches: 617.3953704833984
# 	Loss for last 5 batches: 627.460319519043
# 	Loss for last 5 batches: 632.5948257446289
# 	Loss for last 5 batches: 619.7272109985352
# 	Loss for last 5 batches: 620.7723999023438
# 	Loss for last 5 batches: 617.3705673217773
# 	Loss for last 5 batches: 628.4448776245117
# 	Loss for last 5 batches: 630.3217544555664
# 	Loss for last 5 batches: 625.9210205078125
# 	Loss for last 5 batches: 621.0391464233398
# 	Loss for last 5 batches: 618.7626419067383
# 	Loss for last 5 batches: 628.0502395629883
# 	Loss for last 5 batches: 619.7781677246094
# 	Loss for last 5 batches: 613.5756301879883
# 	Loss for last 5 batches: 628.6301879882812
# 	Loss for last 5 batches: 632.8860244750977
# 	Loss for last 5 batches: 621.3149871826172
# 	Loss for last 5 batches: 622.7902755737305
# 	Loss for last 5 batches: 621.0152282714844
# 	Loss for last 5 batches: 630.7427368164062
# 	Loss for last 5 batches: 625.7373580932617
# 	Loss for last 5 batches: 619.9522171020508
# 	Loss for last 5 batches: 609.9272613525391
# 	Loss for last 5 batches: 631.1199493408203
# 	Loss for last 5 batches: 619.3467864990234
# 	Loss for last 5 batches: 637.5782775878906
# 	Loss for last 5 batches: 613.1229629516602
# 	Loss for last 5 batches: 624.166877746582
# 	Loss for last 5 batches: 629.6839218139648
# 	Loss for last 5 batches: 629.0037231445312
# 	Loss for last 5 batches: 617.02978515625
# 	Loss for last 5 batches: 631.6799545288086
# 	Loss for last 5 batches: 614.1914138793945
# 	Loss for last 5 batches: 612.5082702636719
# 	Loss for last 5 batches: 617.2675399780273
# 	Loss for last 5 batches: 627.4835433959961
# 	Loss for last 5 batches: 613.9255676269531
# 	Loss for last 5 batches: 617.7372207641602
# 	Loss for last 5 batches: 618.3503570556641
# 	Loss for last 5 batches: 630.3298263549805
# 	Loss for last 5 batches: 617.7735214233398
# 	Loss for last 5 batches: 619.420654296875
# 	Loss for last 5 batches: 624.6958465576172
# 	Loss for last 5 batches: 615.7722702026367
# 	Loss for last 5 batches: 631.7162857055664
# 	Loss for last 5 batches: 614.6272811889648
# 	Loss for last 5 batches: 615.549072265625
# 	Loss for last 5 batches: 630.9357376098633
# 	Loss for last 5 batches: 618.4538269042969
# 	Loss for last 5 batches: 628.9734039306641
# 	Loss for last 5 batches: 607.7630233764648
# 	Loss for last 5 batches: 622.1820602416992
# 	Loss for last 5 batches: 616.0165252685547
# 	Loss for last 5 batches: 621.776741027832
# 	Loss for last 5 batches: 620.2970428466797
# 	Loss for last 5 batches: 621.1686935424805
# 	Loss for last 5 batches: 625.9074249267578
# 	Loss for last 5 batches: 626.0116577148438
# 	Loss for last 5 batches: 606.5894241333008
# 	Loss for last 5 batches: 614.6164932250977
# 	Loss for last 5 batches: 609.1846008300781
# 	Loss for last 5 batches: 607.608512878418
# 	Loss for last 5 batches: 618.7695541381836
# 	Loss for last 5 batches: 625.0377502441406
# 	Loss for last 5 batches: 608.91455078125
# 	Loss for last 5 batches: 621.4115982055664
# 	Loss for last 5 batches: 616.9331207275391
# 	Loss for last 5 batches: 618.1416015625
# 	Loss for last 5 batches: 622.7640228271484
# 	Loss for last 5 batches: 626.2033538818359
# 	Loss for last 5 batches: 622.2298965454102
# 	Loss for last 5 batches: 610.9800567626953
# 	Loss for last 5 batches: 615.9683685302734
# 	Loss for last 5 batches: 617.123908996582
# 	Loss for last 5 batches: 626.7022857666016
# 	Loss for last 5 batches: 621.9936294555664
# 	Loss for last 5 batches: 625.3110504150391
# 	Loss for last 5 batches: 626.0264358520508
# 	Loss for last 5 batches: 611.6714630126953
# 	Loss for last 5 batches: 629.7337493896484
# 	Loss for last 5 batches: 608.7556076049805
# 	Loss for last 5 batches: 619.0861053466797
# 	Loss for last 5 batches: 604.0349044799805
# 	Loss for last 5 batches: 615.3136520385742
# 	Loss for last 5 batches: 629.651252746582
# 	Loss for last 5 batches: 619.0815811157227
# 	Loss for last 5 batches: 623.7612533569336
# 	Loss for last 5 batches: 614.6008071899414
# 	Loss for last 5 batches: 618.7633438110352
# 	Loss for last 5 batches: 635.8558197021484
# 	Loss for last 5 batches: 618.353630065918
# 	Loss for last 5 batches: 615.2984924316406
# 	Loss for last 5 batches: 619.7208251953125
# 	Loss for last 5 batches: 611.6165084838867
# 	Loss for last 5 batches: 617.2171325683594
# 	Loss for last 5 batches: 606.2967834472656
# 	Loss for last 5 batches: 615.6677398681641
# 	Loss for last 5 batches: 608.006706237793
# 	Loss for last 5 batches: 624.9414520263672
# 	Loss for last 5 batches: 628.8841018676758
# 	Loss for last 5 batches: 613.2264175415039
# 	Loss for last 5 batches: 620.6385040283203
# 	Loss for last 5 batches: 626.5125427246094
# 	Loss for last 5 batches: 618.3290405273438
# 	Loss for last 5 batches: 640.4043121337891
# 	Loss for last 5 batches: 629.9641418457031
# 	Loss for last 5 batches: 603.6567230224609
# 	Loss for last 5 batches: 637.7717056274414
# 	Loss for last 5 batches: 619.4543914794922
# 	Loss for last 5 batches: 621.7620468139648
# 	Loss for last 5 batches: 621.2698059082031
# 	Loss for last 5 batches: 614.9334259033203
# 	Loss for last 5 batches: 617.2947235107422
# 	Loss for last 5 batches: 615.4268798828125
# 	Loss for last 5 batches: 620.6071624755859
# 	Loss for last 5 batches: 625.1906814575195
# 	Loss for last 5 batches: 628.0029449462891
# 	Loss for last 5 batches: 618.2244338989258
# 	Loss for last 5 batches: 618.4833526611328
# 	Loss for last 5 batches: 623.7795257568359
# 	Loss for last 5 batches: 629.0427703857422
# 	Loss for last 5 batches: 615.5578460693359
# 	Loss for last 5 batches: 624.552978515625
# 	Loss for last 5 batches: 622.757438659668
# 	Loss for last 5 batches: 619.0261306762695
# 	Loss for last 5 batches: 622.6587219238281
# 	Loss for last 5 batches: 621.1754150390625
# 	Loss for last 5 batches: 622.6700973510742
# 	Loss for last 5 batches: 617.5886840820312
# 	Loss for last 5 batches: 625.8371810913086
# 	Loss for last 5 batches: 616.8326721191406
# 	Loss for last 5 batches: 622.8044281005859
# 	Loss for last 5 batches: 621.2694854736328
# 	Loss for last 5 batches: 617.2003479003906
# 	Loss for last 5 batches: 617.9424362182617
# 	Loss for last 5 batches: 616.7885131835938
# 	Loss for last 5 batches: 624.3287887573242
# 	Loss for last 5 batches: 634.9415740966797
# 	Loss for last 5 batches: 613.8180618286133
# 	Loss for last 5 batches: 613.6225814819336
# 	Loss for last 5 batches: 611.1263275146484
# 	Loss for last 5 batches: 625.8172760009766
# 	Loss for last 5 batches: 619.0868453979492
# 	Loss for last 5 batches: 617.0950927734375
# 	Loss for last 5 batches: 614.8603973388672
# 	Loss for last 5 batches: 611.6035690307617
# 	Loss for last 5 batches: 629.7693176269531
# 	Loss for last 5 batches: 624.9328155517578
# 	Loss for last 5 batches: 621.3272857666016
# 	Loss for last 5 batches: 633.8484725952148
# 	Loss for last 5 batches: 629.9035720825195
# 	Loss for last 5 batches: 629.0602264404297
# 	Loss for last 5 batches: 620.0978469848633
# 	Loss for last 5 batches: 611.8436584472656
# 	Loss for last 5 batches: 621.3738632202148
# 	Loss for last 5 batches: 622.95849609375
# 	Loss for last 5 batches: 619.986701965332
# 	Loss for last 5 batches: 627.7967834472656
# 	Loss for last 5 batches: 625.9235153198242
# 	Loss for last 5 batches: 620.4632797241211
# 	Loss for last 5 batches: 622.6986770629883
# 	Loss for last 5 batches: 625.1645584106445
# 	Loss for last 5 batches: 625.1583404541016
# 	Loss for last 5 batches: 625.9526443481445
# 	Loss for last 5 batches: 622.1227951049805
# 	Loss for last 5 batches: 620.9117889404297
# 	Loss for last 5 batches: 617.3937911987305
# 	Loss for last 5 batches: 626.2500152587891
# 	Loss for last 5 batches: 623.2254943847656
# 	Loss for last 5 batches: 619.6178283691406
# 	Loss for last 5 batches: 613.6550521850586
# 	Loss for last 5 batches: 621.38623046875
# 	Loss for last 5 batches: 636.4897689819336
# 	Loss for last 5 batches: 621.1950454711914
# 	Loss for last 5 batches: 635.794303894043
# 	Loss for last 5 batches: 616.162353515625
# 	Loss for last 5 batches: 613.3436584472656
# 	Loss for last 5 batches: 629.964714050293
# 	Loss for last 5 batches: 618.8776931762695
# 	Loss for last 5 batches: 622.5824813842773
# 	Loss for last 5 batches: 625.2511215209961
# 	Loss for last 5 batches: 613.0766983032227
# 	Loss for last 5 batches: 624.8994522094727
# 	Loss for last 5 batches: 623.3584594726562
# 	Loss for last 5 batches: 629.1494293212891
# 	Loss for last 5 batches: 625.8898544311523
# 	Loss for last 5 batches: 613.6149673461914
# 	Loss for last 5 batches: 617.6981201171875
# 	Loss for last 5 batches: 609.5687713623047
# 	Loss for last 5 batches: 625.9713592529297
# 	Loss for last 5 batches: 617.4852142333984
# 	Loss for last 5 batches: 617.9302978515625
# 	Loss for last 5 batches: 616.8727874755859
# 	Loss for last 5 batches: 616.0461654663086
# 	Loss for last 5 batches: 623.3035659790039
# 	Loss for last 5 batches: 620.0300140380859
# 	Loss for last 5 batches: 629.4369430541992
# 	Loss for last 5 batches: 614.4391479492188
# 	Loss for last 5 batches: 622.6971893310547
# 	Loss for last 5 batches: 618.0426635742188
# 	Loss for last 5 batches: 609.0498123168945
# 	Loss for last 5 batches: 619.5026245117188
# 	Loss for last 5 batches: 632.0052719116211
# 	Loss for last 5 batches: 610.1076278686523
# 	Loss for last 5 batches: 611.8996887207031
# 	Loss for last 5 batches: 613.4152069091797
# 	Loss for last 5 batches: 634.3896636962891
# 	Loss for last 5 batches: 632.7308731079102
# 	Loss for last 5 batches: 616.6903076171875
# 	Loss for last 5 batches: 614.82666015625
# 	Loss for last 5 batches: 630.339973449707
# 	Loss for last 5 batches: 632.4013442993164
# 	Loss for last 5 batches: 631.2430801391602
# 	Loss for last 5 batches: 627.7123260498047
# 	Loss for last 5 batches: 637.089729309082
# 	Loss for last 5 batches: 611.0653076171875
# 	Loss for last 5 batches: 621.7093811035156
# 	Loss for last 5 batches: 609.1171035766602
# 	Loss for last 5 batches: 624.4273223876953
# 	Loss for last 5 batches: 624.5927352905273
# 	Loss for last 5 batches: 625.4973373413086
# 	Loss for last 5 batches: 621.7590179443359
# 	Loss for last 5 batches: 620.8193893432617
# 	Loss for last 5 batches: 627.3851547241211
# 	Loss for last 5 batches: 612.9369735717773
# 	Loss for last 5 batches: 628.2051086425781
# 	Loss for last 5 batches: 623.9485931396484
# 	Loss for last 5 batches: 623.9290924072266
# 	Loss for last 5 batches: 623.2254180908203
# 	Loss for last 5 batches: 615.1893463134766
# 	Loss for last 5 batches: 615.5010223388672
# 	Loss for last 5 batches: 606.6387786865234
# 	Loss for last 5 batches: 623.2517852783203
# 	Loss for last 5 batches: 623.9804992675781
# 	Loss for last 5 batches: 615.5662078857422
# 	Loss for last 5 batches: 614.3458633422852
# 	Loss for last 5 batches: 626.9800796508789
# 	Loss for last 5 batches: 613.5945739746094
# 	Loss for last 5 batches: 629.2605361938477
# 	Loss for last 5 batches: 635.3556594848633
# 	Loss for last 5 batches: 633.708854675293
# 	Loss for last 5 batches: 631.3038177490234
# 	Loss for last 5 batches: 627.335090637207
# 	Loss for last 5 batches: 628.7911224365234
# 	Loss for last 5 batches: 621.1321182250977
# 	Loss for last 5 batches: 612.876579284668
# 	Loss for last 5 batches: 616.6821823120117
# 	Loss for last 5 batches: 622.8611450195312
# 	Loss for last 5 batches: 624.6657180786133
# 	Loss for last 5 batches: 623.4033889770508
# 	Loss for last 5 batches: 616.5380477905273
# 	Loss for last 5 batches: 604.9751586914062
# 	Loss for last 5 batches: 623.124626159668
# 	Loss for last 5 batches: 611.9658126831055
# 	Loss for last 5 batches: 612.2437286376953
# 	Loss for last 5 batches: 620.8473510742188
# 	Loss for last 5 batches: 619.3581161499023
# 	Loss for last 5 batches: 618.6807708740234
# 	Loss for last 5 batches: 622.4516143798828
# 	Loss for last 5 batches: 618.4622497558594
# 	Loss for last 5 batches: 617.2580032348633
# 	Loss for last 5 batches: 622.2152786254883
# 	Loss for last 5 batches: 609.7455978393555
# 	Loss for last 5 batches: 614.6950302124023
# 	Loss for last 5 batches: 611.159294128418
# 	Loss for last 5 batches: 627.346061706543
# 	Loss for last 5 batches: 624.7775344848633
# 	Loss for last 5 batches: 605.2526779174805
# 	Loss for last 5 batches: 626.0544357299805
# 	Loss for last 5 batches: 629.6087875366211
# 	Loss for last 5 batches: 629.2216339111328
# 	Loss for last 5 batches: 618.3650588989258
# 	Loss for last 5 batches: 615.8032379150391
# 	Loss for last 5 batches: 614.0411071777344
# 	Loss for last 5 batches: 614.8107452392578
# 	Loss for last 5 batches: 610.9769668579102
# 	Loss for last 5 batches: 620.0692520141602
# 	Loss for last 5 batches: 627.5895843505859
# 	Loss for last 5 batches: 627.0782623291016
# 	Loss for last 5 batches: 604.4220352172852
# 	Loss for last 5 batches: 624.4084396362305
# 	Loss for last 5 batches: 638.8804092407227
# 	Loss for last 5 batches: 610.6764373779297
# 	Loss for last 5 batches: 629.5024490356445
# 	Loss for last 5 batches: 627.6100692749023
# 	Loss for last 5 batches: 616.5582962036133
# 	Loss for last 5 batches: 618.5951995849609
# 	Loss for last 5 batches: 627.6278533935547
# 	Loss for last 5 batches: 623.8833618164062
# 	Loss for last 5 batches: 614.495246887207
# 	Loss for last 5 batches: 618.3605575561523
# 	Loss for last 5 batches: 623.8806457519531
# 	Loss for last 5 batches: 617.4481201171875
# 	Loss for last 5 batches: 614.0793304443359
# 	Loss for last 5 batches: 616.0540466308594
# 	Loss for last 5 batches: 623.7107543945312
# 	Loss for last 5 batches: 626.300163269043
# 	Loss for last 5 batches: 629.7029876708984
# 	Loss for last 5 batches: 628.7362594604492
# 	Loss for last 5 batches: 623.3335876464844
# 	Loss for last 5 batches: 617.5998229980469
# 	Loss for last 5 batches: 621.4711151123047
# 	Loss for last 5 batches: 619.0379180908203
# 	Loss for last 5 batches: 609.3747711181641
# 	Loss for last 5 batches: 615.1635513305664
# 	Loss for last 5 batches: 622.1051254272461
# 	Loss for last 5 batches: 627.423469543457
# 	Loss for last 5 batches: 629.3079452514648
# 	Loss for last 5 batches: 622.072151184082
# 	Loss for last 5 batches: 623.7713241577148
# 	Loss for last 5 batches: 624.9899215698242
# 	Loss for last 5 batches: 611.3786849975586
# 	Loss for last 5 batches: 611.5485305786133
# 	Loss for last 5 batches: 617.7333450317383
# 	Loss for last 5 batches: 616.8922882080078
# 	Loss for last 5 batches: 620.4868545532227
# 	Loss for last 5 batches: 618.9091033935547
# 	Loss for last 5 batches: 626.1132125854492
# 	Loss for last 5 batches: 615.2046432495117
# 	Loss for last 5 batches: 623.955078125
# 	Loss for last 5 batches: 614.5669403076172
# 	Loss for last 5 batches: 617.7656631469727
# 	Loss for last 5 batches: 621.6399459838867
# 	Loss for last 5 batches: 606.0004196166992
# 	Loss for last 5 batches: 636.6131439208984
# 	Loss for last 5 batches: 615.8760833740234
# 	Loss for last 5 batches: 633.8162612915039
# 	Loss for last 5 batches: 616.8188705444336
# 	Loss for last 5 batches: 620.7864990234375
# 	Loss for last 5 batches: 608.1954879760742
# 	Loss for last 5 batches: 627.7017288208008
# 	Loss for last 5 batches: 625.966911315918
# 	Loss for last 5 batches: 623.8455657958984
# 	Loss for last 5 batches: 626.749626159668
# 	Loss for last 5 batches: 623.4810333251953
# 	Loss for last 5 batches: 610.6095123291016
# 	Loss for last 5 batches: 630.6283416748047
# 	Loss for last 5 batches: 611.5072555541992
# 	Loss for last 5 batches: 610.8447189331055
# 	Loss for last 5 batches: 627.940299987793
# 	Loss for last 5 batches: 617.790641784668
# 	Loss for last 5 batches: 622.3339691162109
# 	Loss for last 5 batches: 629.5185775756836
# 	Loss for last 5 batches: 631.8074417114258
# 	Loss for last 5 batches: 624.0132064819336
# 	Loss for last 5 batches: 621.4009017944336
# 	Loss for last 5 batches: 615.9284057617188
# 	Loss for last 5 batches: 628.1218948364258
# 	Loss for last 5 batches: 627.5691375732422
# 	Loss for last 5 batches: 623.9623413085938
# 	Loss for last 5 batches: 624.0037994384766
# 	Loss for last 5 batches: 620.9479370117188
# 	Loss for last 5 batches: 621.9341506958008
# 	Loss for last 5 batches: 620.9587936401367
# 	Loss for last 5 batches: 604.6691513061523
# 	Loss for last 5 batches: 618.0068893432617
# 	Loss for last 5 batches: 618.4175491333008
# 	Loss for last 5 batches: 624.1919860839844
# 	Loss for last 5 batches: 627.7868804931641
# 	Loss for last 5 batches: 614.2021026611328
# 	Loss for last 5 batches: 626.2320556640625
# 	Loss for last 5 batches: 634.4472503662109
# 	Loss for last 5 batches: 629.9811782836914
# 	Loss for last 5 batches: 622.6153411865234
# 	Loss for last 5 batches: 634.0901794433594
# 	Loss for last 5 batches: 622.3762588500977
# 	Loss for last 5 batches: 631.7742385864258
# 	Loss for last 5 batches: 647.3358154296875
# 	Loss for last 5 batches: 634.645263671875
# 	Loss for last 5 batches: 630.6584777832031
# 	Loss for last 5 batches: 627.2529830932617
# 	Loss for last 5 batches: 633.9369964599609
# 	Loss for last 5 batches: 621.2231292724609
# 	Loss for last 5 batches: 629.6318435668945
# 	Loss for last 5 batches: 614.1593780517578
# 	Loss for last 5 batches: 638.6017837524414
# 	Loss for last 5 batches: 626.447265625
# 	Loss for last 5 batches: 624.1938095092773
# 	Loss for last 5 batches: 624.0128479003906
# 	Loss for last 5 batches: 616.1313400268555
# 	Loss for last 5 batches: 625.7680282592773
# 	Loss for last 5 batches: 623.2594833374023
# 	Loss for last 5 batches: 630.4205780029297
# 	Loss for last 5 batches: 625.5739059448242
# 	Loss for last 5 batches: 618.6366958618164
# 	Loss for last 5 batches: 623.3612213134766
# 	Loss for last 5 batches: 632.5644149780273
# 	Loss for last 5 batches: 626.1778182983398
# 	Loss for last 5 batches: 621.9610214233398
# 	Loss for last 5 batches: 627.1833114624023
# 	Loss for last 5 batches: 619.5562133789062
# 	Loss for last 5 batches: 616.6346206665039
# 	Loss for last 5 batches: 615.6590042114258
# 	Loss for last 5 batches: 622.3047409057617
# 	Loss for last 5 batches: 614.9336242675781
# 	Loss for last 5 batches: 617.2127075195312
# 	Loss for last 5 batches: 631.361328125
# 	Loss for last 5 batches: 632.2788925170898
# 	Loss for last 5 batches: 625.6183929443359
# 	Loss for last 5 batches: 626.290641784668
# 	Loss for last 5 batches: 624.3735046386719
# 	Loss for last 5 batches: 617.4636535644531
# 	Loss for last 5 batches: 619.6432800292969
# 	Loss for last 5 batches: 617.9679565429688
# 	Loss for last 5 batches: 613.4848556518555
# 	Loss for last 5 batches: 616.451301574707
# 	Loss for last 5 batches: 628.3009033203125
# 	Loss for last 5 batches: 614.2290802001953
# 	Loss for last 5 batches: 618.673210144043
# 	Loss for last 5 batches: 617.6275329589844
# 	Loss for last 5 batches: 618.7101364135742
# 	Loss for last 5 batches: 619.6160583496094
# 	Loss for last 5 batches: 624.8491363525391
# 	Loss for last 5 batches: 615.5050888061523
# 	Loss for last 5 batches: 612.3326416015625
# 	Loss for last 5 batches: 629.6393737792969
# 	Loss for last 5 batches: 624.2436294555664
# 	Loss for last 5 batches: 629.9244384765625
# 	Loss for last 5 batches: 622.5895309448242
# 	Loss for last 5 batches: 636.3408279418945
# 	Loss for last 5 batches: 629.6943130493164
# 	Loss for last 5 batches: 621.6730804443359
# 	Loss for last 5 batches: 617.7198257446289
# 	Loss for last 5 batches: 612.3190002441406
# 	Loss for last 5 batches: 624.5035781860352
# 	Loss for last 5 batches: 618.073371887207
# 	Loss for last 5 batches: 625.9790191650391
# 	Loss for last 5 batches: 606.1526107788086
# 	Loss for last 5 batches: 628.2806091308594
# 	Loss for last 5 batches: 613.1788024902344
# 	Loss for last 5 batches: 631.5429763793945
# 	Loss for last 5 batches: 609.4814147949219
# 	Loss for last 5 batches: 603.0694580078125
# 	Loss for last 5 batches: 601.6453094482422
# 	Loss for last 5 batches: 628.9314651489258
# 	Loss for last 5 batches: 614.5811233520508
# 	Loss for last 5 batches: 622.1701278686523
# 	Loss for last 5 batches: 627.0622024536133
# 	Loss for last 5 batches: 613.4363784790039
# 	Loss for last 5 batches: 618.9371719360352
# 	Loss for last 5 batches: 611.0765838623047
# 	Loss for last 5 batches: 614.1610641479492
# 	Loss for last 5 batches: 617.9109649658203
# 	Loss for last 5 batches: 610.6258010864258
# 	Loss for last 5 batches: 623.3055648803711
# 	Loss for last 5 batches: 622.9566802978516
# 	Loss for last 5 batches: 641.4322662353516
# 	Loss for last 5 batches: 609.4737777709961
# 	Loss for last 5 batches: 615.0570220947266
# 	Loss for last 5 batches: 617.5933380126953
# 	Loss for last 5 batches: 622.3287963867188
# 	Loss for last 5 batches: 628.5329055786133
# 	Loss for last 5 batches: 638.9758682250977
# 	Loss for last 5 batches: 622.3052062988281
# 	Loss for last 5 batches: 624.7809677124023
# 	Loss for last 5 batches: 610.2821502685547
# 	Loss for last 5 batches: 618.7693481445312
# 	Loss for last 5 batches: 631.1143264770508
# 	Loss for last 5 batches: 618.9556121826172
# 	Loss for last 5 batches: 612.9322280883789
# 	Loss for last 5 batches: 621.1752700805664
# 	Loss for last 5 batches: 627.8999710083008
# 	Loss for last 5 batches: 620.1059799194336
# 	Loss for last 5 batches: 613.9973907470703
# 	Loss for last 5 batches: 610.3183975219727
# 	Loss for last 5 batches: 622.5780029296875
# 	Loss for last 5 batches: 630.8496932983398
# 	Loss for last 5 batches: 621.0686416625977
# 	Loss for last 5 batches: 619.3353271484375
# 	Loss for last 5 batches: 607.7226486206055
# 	Loss for last 5 batches: 622.8734359741211
# 	Loss for last 5 batches: 624.2911071777344
# 	Loss for last 5 batches: 626.2291107177734
# 	Loss for last 5 batches: 611.5248641967773
# 	Loss for last 5 batches: 625.8623504638672
# 	Loss for last 5 batches: 625.0358963012695
# 	Loss for last 5 batches: 623.1060638427734
# 	Loss for last 5 batches: 631.56884765625
# 	Loss for last 5 batches: 624.3376617431641
# 	Loss for last 5 batches: 636.0948715209961
# 	Loss for last 5 batches: 641.2604827880859
# 	Loss for last 5 batches: 622.6788482666016
# 	Loss for last 5 batches: 629.7243499755859
# 	Loss for last 5 batches: 622.2203674316406
# 	Loss for last 5 batches: 627.4392776489258
# 	Loss for last 5 batches: 621.3538360595703
# 	Loss for last 5 batches: 626.4593124389648
# 	Loss for last 5 batches: 623.2588272094727
# 	Loss for last 5 batches: 612.1301193237305
# 	Loss for last 5 batches: 623.8116760253906
# 	Loss for last 5 batches: 620.2255859375
# 	Loss for last 5 batches: 619.5389785766602
# 	Loss for last 5 batches: 621.6463012695312
# 	Loss for last 5 batches: 634.5682754516602
# 	Loss for last 5 batches: 625.2084426879883
# 	Loss for last 5 batches: 624.8352966308594
# 	Loss for last 5 batches: 633.5164566040039
# 	Loss for last 5 batches: 627.1563110351562
# 	Loss for last 5 batches: 625.7212829589844
# 	Loss for last 5 batches: 616.5391235351562
# 	Loss for last 5 batches: 623.6807327270508
# 	Loss for last 5 batches: 614.4197006225586
# 	Loss for last 5 batches: 612.2201690673828
# 	Loss for last 5 batches: 620.3474960327148
# 	Loss for last 5 batches: 626.0092010498047
# 	Loss for last 5 batches: 621.0910949707031
# 	Loss for last 5 batches: 627.101203918457
# 	Loss for last 5 batches: 624.9694671630859
# 	Loss for last 5 batches: 626.4357452392578
# 	Loss for last 5 batches: 633.9826583862305
# 	Loss for last 5 batches: 619.7064666748047
# 	Loss for last 5 batches: 619.5982666015625
# 	Loss for last 5 batches: 620.8780670166016
# 	Loss for last 5 batches: 620.6679916381836
# 	Loss for last 5 batches: 631.8873443603516
# 	Loss for last 5 batches: 618.2284088134766
# 	Loss for last 5 batches: 620.5471572875977
# 	Loss for last 5 batches: 634.6077728271484
# 	Loss for last 5 batches: 637.7722091674805
# 	Loss for last 5 batches: 622.8096084594727
# 	Loss for last 5 batches: 626.003791809082
# 	Loss for last 5 batches: 636.9973297119141
# 	Loss for last 5 batches: 622.5137329101562
# 	Loss for last 5 batches: 626.8630752563477
# 	Loss for last 5 batches: 612.2095642089844
# 	Loss for last 5 batches: 615.6805725097656
# 	Loss for last 5 batches: 619.3927993774414
# 	Loss for last 5 batches: 620.3011474609375
# 	Loss for last 5 batches: 630.3457183837891
# 	Loss for last 5 batches: 627.368766784668
# 	Loss for last 5 batches: 621.5578231811523
# 	Loss for last 5 batches: 610.8286056518555
# 	Loss for last 5 batches: 619.7188491821289
# 	Loss for last 5 batches: 619.4940032958984
# 	Loss for last 5 batches: 624.1002655029297
# 	Loss for last 5 batches: 625.1920394897461
# 	Loss for last 5 batches: 629.7084197998047
# 	Loss for last 5 batches: 627.9179534912109
# 	Loss for last 5 batches: 613.9829254150391
# 	Loss for last 5 batches: 624.980598449707
# 	Loss for last 5 batches: 616.7021865844727
# 	Loss for last 5 batches: 624.9513778686523
# 	Loss for last 5 batches: 622.1595993041992
# 	Loss for last 5 batches: 615.4609222412109
# 	Loss for last 5 batches: 626.4828338623047
# 	Loss for last 5 batches: 627.5365447998047
# 	Loss for last 5 batches: 617.1304168701172
# 	Loss for last 5 batches: 629.9096908569336
# 	Loss for last 5 batches: 622.3337936401367
# 	Loss for last 5 batches: 625.7954025268555
# 	Loss for last 5 batches: 616.3965835571289
# 	Loss for last 5 batches: 609.6829223632812
# 	Loss for last 5 batches: 630.7381362915039
# 	Loss for last 5 batches: 623.9415893554688
# 	Loss for last 5 batches: 629.0830078125
# 	Loss for last 5 batches: 633.5076751708984
# 	Loss for last 5 batches: 615.8401565551758
# 	Loss for last 5 batches: 624.7502288818359
# 	Loss for last 5 batches: 629.5719909667969
# 	Loss for last 5 batches: 610.4433364868164
# 	Loss for last 5 batches: 623.6683883666992
# 	Loss for last 5 batches: 626.4543228149414
# 	Loss for last 5 batches: 625.8533248901367
# 	Loss for last 5 batches: 612.3613433837891
# 	Loss for last 5 batches: 615.063346862793
# 	Loss for last 5 batches: 614.5140991210938
# 	Loss for last 5 batches: 606.8442153930664
# 	Loss for last 5 batches: 620.3646011352539
# 	Loss for last 5 batches: 627.5100784301758
# 	Loss for last 5 batches: 622.9140243530273
# 	Loss for last 5 batches: 625.0919952392578
# 	Loss for last 5 batches: 625.4776229858398
# 	Loss for last 5 batches: 621.2655944824219
# 	Loss for last 5 batches: 619.7667388916016
# 	Loss for last 5 batches: 613.1808624267578
# 	Loss for last 5 batches: 616.9790496826172
# 	Loss for last 5 batches: 632.5842742919922
# 	Loss for last 5 batches: 625.6750564575195
# 	Loss for last 5 batches: 623.3832778930664
# 	Loss for last 5 batches: 619.524299621582
# 	Loss for last 5 batches: 620.8372192382812
# 	Loss for last 5 batches: 620.2947845458984
# 	Loss for last 5 batches: 626.5090103149414
# 	Loss for last 5 batches: 635.8351898193359
# 	Loss for last 5 batches: 618.6343231201172
# 	Loss for last 5 batches: 633.5983428955078
# 	Loss for last 5 batches: 626.6755599975586
# 	Loss for last 5 batches: 620.5847091674805
# 	Loss for last 5 batches: 617.3521575927734
# 	Loss for last 5 batches: 629.7732086181641
# 	Loss for last 5 batches: 618.4908065795898
# 	Loss for last 5 batches: 624.0500564575195
# 	Loss for last 5 batches: 622.7342071533203
# 	Loss for last 5 batches: 621.5780639648438
# 	Loss for last 5 batches: 622.7969131469727
# 	Loss for last 5 batches: 632.5230407714844
# 	Loss for last 5 batches: 623.6845550537109
# 	Loss for last 5 batches: 614.7572479248047
# 	Loss for last 5 batches: 625.0698165893555
# 	Loss for last 5 batches: 625.7098388671875
# 	Loss for last 5 batches: 615.1552352905273
# 	Loss for last 5 batches: 627.0294647216797
# 	Loss for last 5 batches: 627.3939361572266
# 	Loss for last 5 batches: 624.9761505126953
# 	Loss for last 5 batches: 622.5415191650391
# 	Loss for last 5 batches: 609.0498580932617
# 	Loss for last 5 batches: 634.3054122924805
# 	Loss for last 5 batches: 610.3964385986328
# 	Loss for last 5 batches: 633.5115966796875
# 	Loss for last 5 batches: 621.6288070678711
# 	Loss for last 5 batches: 627.7809143066406
# 	Loss for last 5 batches: 623.165397644043
# 	Loss for last 5 batches: 629.7230529785156
# 	Loss for last 5 batches: 619.5504302978516
# 	Loss for last 5 batches: 629.0343780517578
# 	Loss for last 5 batches: 629.5511322021484
# 	Loss for last 5 batches: 627.3349533081055
# 	Loss for last 5 batches: 616.6018829345703
# 	Loss for last 5 batches: 626.9765396118164
# 	Loss for last 5 batches: 608.3424072265625
# 	Loss for last 5 batches: 613.4745483398438
# 	Loss for last 5 batches: 629.0268630981445
# 	Loss for last 5 batches: 611.6972961425781
# 	Loss for last 5 batches: 616.9470443725586
# 	Loss for last 5 batches: 624.5128631591797
# 	Loss for last 5 batches: 610.9565658569336
# 	Loss for last 5 batches: 617.080696105957
# 	Loss for last 5 batches: 625.4810638427734
# 	Loss for last 5 batches: 622.7465286254883
# 	Loss for last 5 batches: 623.0816650390625
# 	Loss for last 5 batches: 620.704475402832
# 	Loss for last 5 batches: 614.6616439819336
# 	Loss for last 5 batches: 633.3330535888672
# 	Loss for last 5 batches: 619.6332244873047
# 	Loss for last 5 batches: 628.2474517822266
# 	Loss for last 5 batches: 620.9577789306641
# 	Loss for last 5 batches: 639.1374206542969
# 	Loss for last 5 batches: 632.6016082763672
# 	Loss for last 5 batches: 620.936767578125
# 	Loss for last 5 batches: 627.5052947998047
# 	Loss for last 5 batches: 623.4540100097656
# 	Loss for last 5 batches: 627.8633499145508
# 	Loss for last 5 batches: 614.2211380004883
# 	Loss for last 5 batches: 626.3611755371094
# 	Loss for last 5 batches: 614.5373001098633
# 	Loss for last 5 batches: 622.8747329711914
# 	Loss for last 5 batches: 620.1219635009766
# 	Loss for last 5 batches: 623.7309875488281
# 	Loss for last 5 batches: 618.342155456543
# 	Loss for last 5 batches: 620.1252746582031
# 	Loss for last 5 batches: 626.5112686157227
# 	Loss for last 5 batches: 615.4682540893555
# ...
# 	Loss for last 5 batches: 604.6299285888672
# 	Loss for last 5 batches: 614.8136978149414
# 	Loss for last 5 batches: 625.8637924194336
# 	Loss for last 5 batches: 624.1652526855469
# 	Loss for last 5 batches: 632.1574172973633
# 	Loss for last 5 batches: 620.2325668334961
# 	Loss for last 5 batches: 635.4018402099609
# 	Loss for last 5 batches: 615.9182739257812
# 	Loss for last 5 batches: 626.3158111572266
# 	Loss for last 5 batches: 628.4737777709961
# 	Loss for last 5 batches: 625.9724807739258
# 	Loss for last 5 batches: 624.5066680908203
# 	Loss for last 5 batches: 618.5637741088867
# 	Loss for last 5 batches: 626.0463638305664
# 	Loss for last 5 batches: 617.3865127563477
# 	Loss for last 5 batches: 629.3252334594727
# 	Loss for last 5 batches: 634.673698425293
# 	Loss for last 5 batches: 615.8759536743164
# 	Loss for last 5 batches: 624.3059616088867
# 	Loss for last 5 batches: 619.8373794555664
# 	Loss for last 5 batches: 615.8214721679688
# 	Loss for last 5 batches: 611.8129272460938
# 	Loss for last 5 batches: 629.7280044555664
# 	Loss for last 5 batches: 622.7294845581055
# 	Loss for last 5 batches: 622.1001434326172
# 	Loss for last 5 batches: 628.7899780273438
# 	Loss for last 5 batches: 615.7160186767578
# 	Loss for last 5 batches: 637.3952713012695
# 	Loss for last 5 batches: 606.6923828125
# 	Loss for last 5 batches: 621.3219909667969
# 	Loss for last 5 batches: 616.0946731567383
# 	Loss for last 5 batches: 605.5335159301758
# 	Loss for last 5 batches: 627.585807800293
# 	Loss for last 5 batches: 602.0559997558594
# 	Loss for last 5 batches: 620.5501556396484
# 	Loss for last 5 batches: 624.6182098388672
# 	Loss for last 5 batches: 621.8102416992188
# 	Loss for last 5 batches: 622.8886871337891
# 	Loss for last 5 batches: 635.15234375
# 	Loss for last 5 batches: 624.5530853271484
# 	Loss for last 5 batches: 623.7943725585938
# 	Loss for last 5 batches: 619.5287933349609
# 	Loss for last 5 batches: 624.7071914672852
# 	Loss for last 5 batches: 621.2829132080078
# 	Loss for last 5 batches: 630.2686386108398
# 	Loss for last 5 batches: 622.0214004516602
# 	Loss for last 5 batches: 628.0087432861328
# 	Loss for last 5 batches: 625.7063369750977
# 	Loss for last 5 batches: 624.0788040161133
# 	Loss for last 5 batches: 619.0395660400391
# 	Loss for last 5 batches: 628.0057601928711
# 	Loss for last 5 batches: 623.3763656616211
# 	Loss for last 5 batches: 620.9631118774414
# 	Loss for last 5 batches: 617.4109420776367
# 	Loss for last 5 batches: 611.1775054931641
# 	Loss for last 5 batches: 626.625602722168
# 	Loss for last 5 batches: 601.8487167358398
# 	Loss for last 5 batches: 616.6808166503906
# 	Loss for last 5 batches: 625.7763137817383
# 	Loss for last 5 batches: 625.5114898681641
# 	Loss for last 5 batches: 614.9484481811523
# 	Loss for last 5 batches: 610.3701019287109
# 	Loss for last 5 batches: 615.7954254150391
# 	Loss for last 5 batches: 624.5449981689453
# 	Loss for last 5 batches: 635.6538619995117
# 	Loss for last 5 batches: 617.8631744384766
# 	Loss for last 5 batches: 618.1296005249023
# 	Loss for last 5 batches: 616.9509429931641
# 	Loss for last 5 batches: 618.6255950927734
# 	Loss for last 5 batches: 629.4550323486328
# 	Loss for last 5 batches: 630.2865371704102
# 	Loss for last 5 batches: 616.6205673217773
# 	Loss for last 5 batches: 608.8482208251953
# 	Loss for last 5 batches: 614.7853317260742
# 	Loss for last 5 batches: 610.9026641845703
# 	Loss for last 5 batches: 623.1509246826172
# 	Loss for last 5 batches: 622.4880599975586
# 	Loss for last 5 batches: 628.1019515991211
# 	Loss for last 5 batches: 625.7344741821289
# 	Loss for last 5 batches: 619.2395935058594
# 	Loss for last 5 batches: 621.1345138549805
# 	Loss for last 5 batches: 618.4250411987305
# 	Loss for last 5 batches: 617.3445816040039
# 	Loss for last 5 batches: 631.339241027832
# 	Loss for last 5 batches: 633.691047668457
# 	Loss for last 5 batches: 619.4183883666992
# 	Loss for last 5 batches: 621.1331939697266
# 	Loss for last 5 batches: 623.1882934570312
# 	Loss for last 5 batches: 629.8647918701172
# 	Loss for last 5 batches: 629.2255554199219
# 	Loss for last 5 batches: 611.4823913574219
# 	Loss for last 5 batches: 626.9220428466797
# 	Loss for last 5 batches: 630.8975219726562
# 	Loss for last 5 batches: 625.563606262207
# 	Loss for last 5 batches: 613.4940795898438
# 	Loss for last 5 batches: 624.434684753418
# 	Loss for last 5 batches: 627.2169647216797
# 	Loss for last 5 batches: 623.0795516967773
# 	Loss for last 5 batches: 626.0441207885742
# 	Loss for last 5 batches: 624.4382171630859
# 	Loss for last 5 batches: 619.6725234985352
# 	Loss for last 5 batches: 618.8373489379883
# 	Loss for last 5 batches: 631.0837936401367
# 	Loss for last 5 batches: 619.1658096313477
# 	Loss for last 5 batches: 624.4706573486328
# 	Loss for last 5 batches: 611.7306213378906
# 	Loss for last 5 batches: 604.9332809448242
# 	Loss for last 5 batches: 619.0217514038086
# 	Loss for last 5 batches: 623.533447265625
# 	Loss for last 5 batches: 616.5274200439453
# 	Loss for last 5 batches: 620.4790954589844
# 	Loss for last 5 batches: 619.6586074829102
# 	Loss for last 5 batches: 628.0868225097656
# 	Loss for last 5 batches: 610.0486679077148
# 	Loss for last 5 batches: 618.8316650390625
# 	Loss for last 5 batches: 612.3186645507812
# 	Loss for last 5 batches: 615.9858322143555
# 	Loss for last 5 batches: 621.6717910766602
# 	Loss for last 5 batches: 624.1609573364258
# 	Loss for last 5 batches: 629.5911407470703
# 	Loss for last 5 batches: 627.1041946411133
# 	Loss for last 5 batches: 621.576416015625
# 	Loss for last 5 batches: 608.7043914794922
# 	Loss for last 5 batches: 624.0457916259766
# 	Loss for last 5 batches: 619.6779022216797
# 	Loss for last 5 batches: 611.265998840332
# 	Loss for last 5 batches: 620.2198638916016
# 	Loss for last 5 batches: 620.0778198242188
# 	Loss for last 5 batches: 606.6943206787109
# 	Loss for last 5 batches: 612.1004028320312
# 	Loss for last 5 batches: 620.4713287353516
# 	Loss for last 5 batches: 622.9265899658203
# 	Loss for last 5 batches: 630.7756423950195
# 	Loss for last 5 batches: 625.6261215209961
# 	Loss for last 5 batches: 618.3710708618164
# 	Loss for last 5 batches: 626.3212356567383
# 	Loss for last 5 batches: 624.7408828735352
# 	Loss for last 5 batches: 619.2028503417969
# 	Loss for last 5 batches: 628.8258972167969
# 	Loss for last 5 batches: 625.9290237426758
# 	Loss for last 5 batches: 624.7193374633789
# 	Loss for last 5 batches: 621.4927520751953
# 	Loss for last 5 batches: 615.1438522338867
# 	Loss for last 5 batches: 620.7249450683594
# 	Loss for last 5 batches: 626.0158004760742
# 	Loss for last 5 batches: 616.0254211425781
# 	Loss for last 5 batches: 631.7276077270508
# 	Loss for last 5 batches: 632.2565231323242
# 	Loss for last 5 batches: 622.759635925293
# 	Loss for last 5 batches: 611.240234375
# 	Loss for last 5 batches: 635.1577072143555
# 	Loss for last 5 batches: 627.149284362793
# 	Loss for last 5 batches: 622.0669250488281
# 	Loss for last 5 batches: 614.9984436035156
# 	Loss for last 5 batches: 619.9064331054688
# 	Loss for last 5 batches: 630.6446533203125
# 	Loss for last 5 batches: 622.518440246582
# 	Loss for last 5 batches: 620.2038192749023
# 	Loss for last 5 batches: 629.813591003418
# 	Loss for last 5 batches: 617.5109176635742
# 	Loss for last 5 batches: 622.6270599365234
# 	Loss for last 5 batches: 622.977294921875
# 	Loss for last 5 batches: 624.8667755126953
# 	Loss for last 5 batches: 629.8073196411133
# 	Loss for last 5 batches: 622.1313552856445
# 	Loss for last 5 batches: 629.111701965332
# 	Loss for last 5 batches: 616.0930480957031
# 	Loss for last 5 batches: 615.214973449707
# 	Loss for last 5 batches: 620.763542175293
# 	Loss for last 5 batches: 630.2136001586914
# 	Loss for last 5 batches: 631.9077072143555
# 	Loss for last 5 batches: 619.8510208129883
# 	Loss for last 5 batches: 615.0225601196289
# 	Loss for last 5 batches: 616.9824447631836
# 	Loss for last 5 batches: 611.2778930664062
# 	Loss for last 5 batches: 604.296875
# 	Loss for last 5 batches: 623.7285614013672
# 	Loss for last 5 batches: 599.1784515380859
# 	Loss for last 5 batches: 614.7247085571289
# 	Loss for last 5 batches: 607.0470123291016
# 	Loss for last 5 batches: 627.0322494506836
# 	Loss for last 5 batches: 612.1145477294922
# 	Loss for last 5 batches: 625.1609573364258
# 	Loss for last 5 batches: 620.5321426391602
# 	Loss for last 5 batches: 629.2026138305664
# 	Loss for last 5 batches: 608.7162857055664
# 	Loss for last 5 batches: 615.328483581543
# 	Loss for last 5 batches: 629.1499710083008
# 	Loss for last 5 batches: 616.2797546386719
# 	Loss for last 5 batches: 623.3587036132812
# 	Loss for last 5 batches: 617.3998794555664
# 	Loss for last 5 batches: 624.9220809936523
# 	Loss for last 5 batches: 618.3019180297852
# 	Loss for last 5 batches: 615.1113662719727
# 	Loss for last 5 batches: 633.1992111206055
# 	Loss for last 5 batches: 631.4358749389648
# 	Loss for last 5 batches: 613.6025619506836
# 	Loss for last 5 batches: 630.0510025024414
# 	Loss for last 5 batches: 621.3539657592773
# 	Loss for last 5 batches: 611.8664703369141
# 	Loss for last 5 batches: 623.3887023925781
# 	Loss for last 5 batches: 614.6188735961914
# 	Loss for last 5 batches: 616.9275588989258
# 	Loss for last 5 batches: 609.436897277832
# 	Loss for last 5 batches: 631.7483978271484
# 	Loss for last 5 batches: 619.2305450439453
# 	Loss for last 5 batches: 618.1636123657227
# 	Loss for last 5 batches: 627.4131393432617
# 	Loss for last 5 batches: 626.8249969482422
# 	Loss for last 5 batches: 611.4799346923828
# 	Loss for last 5 batches: 611.7952041625977
# 	Loss for last 5 batches: 618.4712905883789
# 	Loss for last 5 batches: 615.0018920898438
# 	Loss for last 5 batches: 623.6625137329102
# 	Loss for last 5 batches: 629.9804611206055
# 	Loss for last 5 batches: 616.1697158813477
# 	Loss for last 5 batches: 610.8595123291016
# 	Loss for last 5 batches: 629.4828720092773
# 	Loss for last 5 batches: 622.2812881469727
# 	Loss for last 5 batches: 622.249153137207
# 	Loss for last 5 batches: 616.3531265258789
# 	Loss for last 5 batches: 617.5606384277344
# 	Loss for last 5 batches: 616.8661880493164
# 	Loss for last 5 batches: 623.9518203735352
# 	Loss for last 5 batches: 620.1334609985352
# 	Loss for last 5 batches: 614.9034652709961
# 	Loss for last 5 batches: 614.2245407104492
# 	Loss for last 5 batches: 627.988395690918
# 	Loss for last 5 batches: 625.2535934448242
# 	Loss for last 5 batches: 621.3028259277344
# 	Loss for last 5 batches: 626.6487884521484
# 	Loss for last 5 batches: 627.2688293457031
# 	Loss for last 5 batches: 624.4614181518555
# 	Loss for last 5 batches: 614.7751617431641
# 	Loss for last 5 batches: 633.295783996582
# 	Loss for last 5 batches: 625.4822387695312
# 	Loss for last 5 batches: 614.3777008056641
# 	Loss for last 5 batches: 611.9348983764648
# 	Loss for last 5 batches: 609.8156509399414
# 	Loss for last 5 batches: 617.7512741088867
# 	Loss for last 5 batches: 635.0576400756836
# 	Loss for last 5 batches: 612.7580413818359
# 	Loss for last 5 batches: 634.3489303588867
# 	Loss for last 5 batches: 616.1956100463867
# 	Loss for last 5 batches: 630.9878692626953
# 	Loss for last 5 batches: 628.4811553955078
# 	Loss for last 5 batches: 623.7777481079102
# 	Loss for last 5 batches: 628.6646957397461
# 	Loss for last 5 batches: 626.2729721069336
# 	Loss for last 5 batches: 622.6766738891602
# 	Loss for last 5 batches: 616.5214004516602
# 	Loss for last 5 batches: 623.6696014404297
# 	Loss for last 5 batches: 634.9882354736328
# 	Loss for last 5 batches: 620.927001953125
# 	Loss for last 5 batches: 618.0553283691406
# 	Loss for last 5 batches: 620.884635925293
# 	Loss for last 5 batches: 633.6620025634766
# 	Loss for last 5 batches: 618.7572784423828
# 	Loss for last 5 batches: 601.3216400146484
# 	Loss for last 5 batches: 625.1102523803711
# 	Loss for last 5 batches: 617.9678192138672
# 	Loss for last 5 batches: 625.8917922973633
# 	Loss for last 5 batches: 622.6147232055664
# 	Loss for last 5 batches: 613.6197814941406
# 	Loss for last 5 batches: 615.9906921386719
# 	Loss for last 5 batches: 626.7644577026367
# 	Loss for last 5 batches: 626.6782379150391
# 	Loss for last 5 batches: 622.2093048095703
# 	Loss for last 5 batches: 626.6065063476562
# 	Loss for last 5 batches: 618.3949432373047
# 	Loss for last 5 batches: 613.0533752441406
# 	Loss for last 5 batches: 623.2016906738281
# 	Loss for last 5 batches: 629.8404693603516
# 	Loss for last 5 batches: 608.0638656616211
# 	Loss for last 5 batches: 631.4308090209961
# 	Loss for last 5 batches: 622.2379989624023
# 	Loss for last 5 batches: 627.3715438842773
# 	Loss for last 5 batches: 618.233757019043
# 	Loss for last 5 batches: 621.8837280273438
# 	Loss for last 5 batches: 620.9385223388672
# 	Loss for last 5 batches: 624.3826065063477
# 	Loss for last 5 batches: 624.5358352661133
# 	Loss for last 5 batches: 619.8423690795898
# 	Loss for last 5 batches: 617.287483215332
# 	Loss for last 5 batches: 614.7769241333008
# 	Loss for last 5 batches: 633.0905227661133
# 	Loss for last 5 batches: 625.7164459228516
# 	Loss for last 5 batches: 618.3063507080078
# 	Loss for last 5 batches: 623.6536026000977
# 	Loss for last 5 batches: 615.711555480957
# 	Loss for last 5 batches: 617.8522338867188
# 	Loss for last 5 batches: 612.8708419799805
# 	Loss for last 5 batches: 626.4466323852539
# 	Loss for last 5 batches: 631.1980133056641
# 	Loss for last 5 batches: 618.0039520263672
# 	Loss for last 5 batches: 628.4903717041016
# 	Loss for last 5 batches: 626.4505386352539
# 	Loss for last 5 batches: 607.6892852783203
# 	Loss for last 5 batches: 618.6730422973633
# 	Loss for last 5 batches: 605.9391937255859
# 	Loss for last 5 batches: 620.4344329833984
# 	Loss for last 5 batches: 619.1823501586914
# 	Loss for last 5 batches: 642.0119934082031
# 	Loss for last 5 batches: 641.9133605957031
# 	Loss for last 5 batches: 630.7358016967773
# 	Loss for last 5 batches: 629.7397689819336
# 	Loss for last 5 batches: 624.9549789428711
# 	Loss for last 5 batches: 631.4666213989258
# 	Loss for last 5 batches: 629.08984375
# 	Loss for last 5 batches: 621.9682312011719
# 	Loss for last 5 batches: 643.8039245605469
# 	Loss for last 5 batches: 624.6669769287109
# 	Loss for last 5 batches: 630.2726440429688
# 	Loss for last 5 batches: 621.1881484985352
# 	Loss for last 5 batches: 633.3690719604492
# 	Loss for last 5 batches: 617.6547164916992
# 	Loss for last 5 batches: 626.2908096313477
# 	Loss for last 5 batches: 627.0009536743164
# 	Loss for last 5 batches: 612.3181762695312
# 	Loss for last 5 batches: 631.2100143432617
# 	Loss for last 5 batches: 622.5827484130859
# 	Loss for last 5 batches: 644.1994781494141
# 	Loss for last 5 batches: 619.7003555297852
# 	Loss for last 5 batches: 610.7204666137695
# 	Loss for last 5 batches: 615.0514526367188
# 	Loss for last 5 batches: 622.7831420898438
# 	Loss for last 5 batches: 626.6129302978516
# 	Loss for last 5 batches: 614.3230361938477
# 	Loss for last 5 batches: 626.9692687988281
# 	Loss for last 5 batches: 610.6695175170898
# 	Loss for last 5 batches: 612.374382019043
# 	Loss for last 5 batches: 613.7032318115234
# 	Loss for last 5 batches: 613.676399230957
# 	Loss for last 5 batches: 614.5807723999023
# 	Loss for last 5 batches: 631.2840423583984
# 	Loss for last 5 batches: 607.381462097168
# 	Loss for last 5 batches: 624.8034515380859
# 	Loss for last 5 batches: 623.5937881469727
# 	Loss for last 5 batches: 631.5429763793945
# 	Loss for last 5 batches: 636.3022155761719
# 	Loss for last 5 batches: 626.2741546630859
# 	Loss for last 5 batches: 623.7040405273438
# 	Loss for last 5 batches: 629.3266296386719
# 	Loss for last 5 batches: 618.7443771362305
# 	Loss for last 5 batches: 624.85400390625
# 	Loss for last 5 batches: 611.7758407592773
# 	Loss for last 5 batches: 632.7023391723633
# 	Loss for last 5 batches: 612.8546905517578
# 	Loss for last 5 batches: 603.4023513793945
# 	Loss for last 5 batches: 619.3019943237305
# 	Loss for last 5 batches: 619.0001525878906
# 	Loss for last 5 batches: 613.969612121582
# 	Loss for last 5 batches: 613.8365097045898
# 	Loss for last 5 batches: 627.5362777709961
# 	Loss for last 5 batches: 617.7236404418945
# 	Loss for last 5 batches: 623.6233901977539
# 	Loss for last 5 batches: 614.5812911987305
# 	Loss for last 5 batches: 599.6281127929688
# 	Loss for last 5 batches: 626.7739334106445
# 	Loss for last 5 batches: 609.1735458374023
# 	Loss for last 5 batches: 618.7493515014648
# 	Loss for last 5 batches: 621.2779159545898
# 	Loss for last 5 batches: 631.0158538818359
# 	Loss for last 5 batches: 609.2898712158203

# %%
torch.save(trainer.current_network.state_dict(), "latest_weights.pth")

# %%
import pickle
len(trainer.replay_buffer)
# Out:
# 100000

# %%
trainer.current_network.eval()
old_agent = AlphaMCTSAgent(control_net = trainer.control_network)
new_agent = AlphaMCTSAgent(control_net = trainer.current_network)

agents = [old_agent, new_agent]

wins = 0
ties = 0

game = NestedTTT()

for game_num in range(100):
    game.reset()
    agents[0].reset()
    agents[1].reset()
    result = 0
    player_num = game_num // 50 #Both take first turn 50 times
    turn_num = 100 #Turn down the temperature

    while len(game.get_valid_moves()) > 0:
        move, _ = agents[player_num].search(game.copy(), turn_num, allotted_playouts = 800)
        _, _ = agents[1 - player_num].search(game.copy(), turn_num, allotted_playouts = 800)

        result = game.make_move(move)
        if not result:
            game.switch_player()
            agents[0].take_action(move)
            agents[1].take_action(move)
            player_num = (player_num + 1) % 2

    if not result:
        print("Game {}: Tie".format(game_num))
        ties += 1
    elif result and player_num == 1:
        print("Game {}: Win".format(game_num))
        wins += 1

if wins + .5 * ties >= 55:
    print("Challenger network won {} games and tied {} games; it becomes new control network".format(wins, ties))
    torch.save(trainer.current_network.state_dict(), "control_weights_{}.pth".format(trainer.n_batches))
    trainer.control_network.load_state_dict(trainer.current_network.state_dict())
else:
    print("Challenger network not sufficiently better; {} wins and {} ties".format(wins, ties))

trainer.control_network.eval()
trainer.current_network.train()
# Out:
# Game 0: Tie
# Game 22: Tie
# Game 25: Tie
# Game 28: Tie
# Game 31: Tie
# Game 54: Tie
# Game 61: Tie
# Game 62: Tie
# Game 63: Tie
# Game 67: Tie
# Game 87: Tie
# Game 93: Tie
# Game 98: Tie
# Challenger network not sufficiently better; 0 wins and 13 ties
# NestedTTTNet(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn_inner): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2_collapse): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (bn_outer): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3_collapse): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1))
#   (bn_linear): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (policy_head): Sequential(
#     (0): Linear(in_features=256, out_features=81, bias=True)
#     (1): Softmax()
#   )
#   (value_head): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#     (3): Tanh()
#   )
# )

# %%
trainer.current_network.load_state_dict(trainer.control_network.state_dict())

# %%
from multiprocessing import Pool, cpu_count

cpu_count()
# Out:
# 8

# %%
pool = Pool(cpu_count()-1)
pool

# %%
def run_train_parallel(trainer):
    print("Starting self-play game")
    trainer.generate_self_play_data(1)
    print("Self play finished, returning buffer contents")
    return list(trainer.replay_buffer.buffer)

# %%
trainers = []
for _ in range(cpu_count()-1):
    trainer = SelfPlayTrainer(AlphaMCTSAgent(), NestedTTT(), weights_file = "control_weights_3000.pth")
    trainers.append(trainer)
results = pool.map(run_train_parallel, trainers)

# %%
results

# %%
print("HI")
